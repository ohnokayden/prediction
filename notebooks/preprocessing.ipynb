# %% [markdown]
# # Preprocessing for model
#
# for finding the best values for scaling factors and other constants
#
# Constants and scaling factors:
# rolling form-> decay factor for both prem and cs teams
# ->use regression-> predict rolling form in the first 5 games?-> predict the form at the start at the start of the szn
#
# Hyperparameters-> use optimisers like optuna/ scikit-optimize
# elo:
# BASE_ELO = 1500.0
# HOME_ADVANTAGE = 60.0
# K_FACTOR = 20.0
# SEASON_REGRESSION = 0.7
# PROMOTED_PENALTY = 100.0
