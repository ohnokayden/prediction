# %%
print("hello ")
# Out:
# hello

# %%
import pandas as pd
df = pd.read_csv("data/1415.csv")
df.isnull().sum()
# Out:
# Div         1
# Date        1
# HomeTeam    1
# AwayTeam    1
# FTHG        1
#            ..
# BbMxAHA     1
# BbAvAHA     1
# PSCH        1
# PSCD        1
# PSCA        1
# Length: 68, dtype: int64

# %%
# generating rolling form for home team
home_team="Liverpool"
away_team="Chelsea"
match_number = df[(df["HomeTeam"] == home_team) & (df["AwayTeam"] == away_team)] 
home = df[df["HomeTeam"].isin([home_team])]  # shows the home team matches for a team
match_number
# Out:
#     Div        Date   Time   HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 349  E0  09/05/2026  12:30  Liverpool  Chelsea     1     1   D     1     1
#
#      ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 349  ...     2.03     1.83    NaN    NaN     2.03     1.84     1.94     1.79
#
#      BFECAHH  BFECAHA
# 349      NaN      NaN
#
# [1 rows x 132 columns]

# %% [markdown]
# for a given match -> find home team games -> find last 6 games(excluding current game)
